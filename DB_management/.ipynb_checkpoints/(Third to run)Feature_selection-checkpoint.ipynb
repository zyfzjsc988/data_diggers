# %%
from pymongo import MongoClient
client = MongoClient('mongodb://localhost:27017')
client.database_names()
db = client.data_diggers
collection = db.training_data

# %% [markdown]
# ## import the package and data

# %%
from pprint import pprint
import numpy
import pymongo
import pandas as pd
from sklearn import linear_model
import sklearn

filter_ = {
                            'house_price':{'$exists':'true'},
#                               'total_jobs':{'$exists':'true'},
#                               'school_number':{'$exists':'true'},
                              'unemployment':{'$exists':'true'},
                              'traffic_noise':{'$exists':'true'},
#                               'hospitals_number':{'$exists':'true'},
                              'population':{'$exists':'true'},
                              'GVA':{'$exists':'true'},
#                               'stations_number':{'$exists':'true'},
                              'happiness':{'$exists':'true'},
#                               'pubs_number':{'$exists':'true'},
                              'road_traffic_2016':{'$exists':'true'},
                             }

all_found = collection.find(filter_)


# read data to pandas
data = pd.DataFrame(list(all_found))
# print(data[0:10])

data = data.fillna(0)
# create target variable
# print(data[0:10])

# remove some columns
data = data.drop(['_id', 'city_name', 'latitude', 'longitude', 'region', 'sample', 'uk_region'], axis=1)

# print(data[0:82])

# %% [markdown]
# # Insert the colum and normalize

# %%
# normalization by z-score 
from sklearn import preprocessing
scaler = preprocessing.StandardScaler()
def scaleColumns(df):
    cols_to_scale = list(df)
    for col in cols_to_scale:
        df[col] = pd.DataFrame(scaler.fit_transform(pd.DataFrame(df[col])),columns=[col])
    return df

# %%
data['hospitals_number_per_person'] = data['hospitals_number']/data['population']
data['pubs_number_per_person'] = data['pubs_number']/data['population']
data['stations_number_per_person'] = data['stations_number']/data['population']
data['school_number_per_person'] = data['school_number']/data['population']
data['total_jobs_per_person'] = data['total_jobs']/data['population']
data['number_of_universities_per_person'] = data['number_of_universities']/data['population']


# # remove some columns
# data = data.drop(['hospitals_number', 'pubs_number', 'stations_number', 'school_number', 'total_jobs', 'number_of_universities'], axis=1)

# normalization by z-score 
data = scaleColumns(data)

# create target variable
target = data['happiness']
# print(target)

# remove happiness from data
data = data.drop(['happiness'], axis=1)
# print(data[0:5])

# %%
data_pandas = data
# convert both to Numpy array representation
data = data.as_matrix()
target = target.as_matrix()

# %% [markdown]
# # Linear regression : Lasso

# %%
# run lasso for feature selection
clf = linear_model.Lasso(alpha=0.0005)
clf.fit(data, target)

alphas = numpy.geomspace(0.00001, 0.1, num=100)
print(alphas)

error = []
for i in alphas:
    
    mean_error = []
    
#     cross validation
    kf = sklearn.model_selection.KFold(4, shuffle=True)
    for train_index, test_index in kf.split(data):
        X_train, X_test = data[train_index], data[test_index]
        Y_train, Y_test = target[train_index], target[test_index]
        
#         train model
        clf = linear_model.Lasso(alpha=i)
        clf.fit(X_train, Y_train)
        
#         error
        mean_error.append(sklearn.metrics.mean_squared_error(Y_test, clf.predict(X_test)))
    
#     error
    error.append(numpy.mean(mean_error))

    
print(error)
print(error.index(min(error)))
print(alphas[error.index(min(error))])

# alpha
alpha = alphas[error.index(min(error))]

clf = linear_model.Lasso(alpha=alpha)
clf.fit(data, target)


weights = clf.coef_
print(weights.tolist())
print(clf.intercept_)
# Out:
# /usr/local/anaconda/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# [  1.00000000e-05   1.09749877e-05   1.20450354e-05   1.32194115e-05
#    1.45082878e-05   1.59228279e-05   1.74752840e-05   1.91791026e-05
#    2.10490414e-05   2.31012970e-05   2.53536449e-05   2.78255940e-05
#    3.05385551e-05   3.35160265e-05   3.67837977e-05   4.03701726e-05
#    4.43062146e-05   4.86260158e-05   5.33669923e-05   5.85702082e-05
#    6.42807312e-05   7.05480231e-05   7.74263683e-05   8.49753436e-05
#    9.32603347e-05   1.02353102e-04   1.12332403e-04   1.23284674e-04
#    1.35304777e-04   1.48496826e-04   1.62975083e-04   1.78864953e-04
#    1.96304065e-04   2.15443469e-04   2.36448941e-04   2.59502421e-04
#    2.84803587e-04   3.12571585e-04   3.43046929e-04   3.76493581e-04
#    4.13201240e-04   4.53487851e-04   4.97702356e-04   5.46227722e-04
#    5.99484250e-04   6.57933225e-04   7.22080902e-04   7.92482898e-04
#    8.69749003e-04   9.54548457e-04   1.04761575e-03   1.14975700e-03
#    1.26185688e-03   1.38488637e-03   1.51991108e-03   1.66810054e-03
#    1.83073828e-03   2.00923300e-03   2.20513074e-03   2.42012826e-03
#    2.65608778e-03   2.91505306e-03   3.19926714e-03   3.51119173e-03
#    3.85352859e-03   4.22924287e-03   4.64158883e-03   5.09413801e-03
#    5.59081018e-03   6.13590727e-03   6.73415066e-03   7.39072203e-03
#    8.11130831e-03   8.90215085e-03   9.77009957e-03   1.07226722e-02
#    1.17681195e-02   1.29154967e-02   1.41747416e-02   1.55567614e-02
#    1.70735265e-02   1.87381742e-02   2.05651231e-02   2.25701972e-02
#    2.47707636e-02   2.71858824e-02   2.98364724e-02   3.27454916e-02
#    3.59381366e-02   3.94420606e-02   4.32876128e-02   4.75081016e-02
#    5.21400829e-02   5.72236766e-02   6.28029144e-02   6.89261210e-02
#    7.56463328e-02   8.30217568e-02   9.11162756e-02   1.00000000e-01]
# [1.6341509526655167, 2.5894612721387258, 2.9925556943919185, 3.1631805593117619, 1.6971211029046267, 3.9380396906122144, 1.693615743623107, 0.90877873132442666, 1.7526829781764894, 1.3882322712410551, 1.3451312558018707, 1.75687034755122, 1.5255209602837547, 1.6684335543734201, 5.4081450161421118, 3.1637502191904971, 3.9777590351098722, 2.6205624405812635, 0.94418530576865156, 1.970573586378586, 2.6632618959019361, 1.7033106730018595, 1.765658716079322, 2.7669882117408284, 1.4114244255901234, 2.1380777528494384, 5.4923981701959761, 2.6447001920735862, 1.3802479065694, 1.4355829268683118, 2.3681926930185186, 0.88171752888374011, 3.2069644118072267, 2.0051521544458684, 2.6992864927360238, 1.6346381850115832, 1.4629428080442359, 3.1201593516797761, 1.2790753182199401, 2.5758047453115878, 1.7520880739797815, 1.5570453082888225, 2.9912150079609141, 2.5795971316200701, 2.1165517306542903, 1.5326802761979901, 1.7923019578950266, 4.47782703556729, 1.5287979540471455, 1.6602653241036911, 1.9374668306695069, 2.00887523239654, 1.3615875837246085, 1.6993385693727321, 2.3888328438374016, 2.8569409634859304, 1.6659746456111402, 1.9135619712012315, 1.4737402323729141, 0.94677054761725143, 0.9912512938157243, 0.69599447969295059, 0.86927231430161478, 2.0715926290313456, 0.83768648828319825, 0.97548943835872071, 1.2780535522398606, 1.2290598130089367, 1.1185897532450253, 0.67654462507459789, 1.0830536063943217, 1.2063787859748527, 0.95824505230649737, 0.97598202491395569, 0.746668896055936, 0.87747378763074724, 0.89855607403183169, 1.01756812934154, 1.1727051214548032, 0.9470493946369164, 1.3223973783337337, 0.78088345958363681, 0.92444039469442041, 0.64366251147200404, 0.9913787851347533, 0.88541712707293962, 1.2349722367765514, 0.71718584471233859, 0.72723081786973742, 0.77376036301365125, 0.78086235114226676, 0.88738135985897193, 0.90663660085623587, 0.77136119395869396, 0.71341429251348043, 0.80954329754911036, 0.7771178850935494, 0.8428196376535747, 0.80354855379538737, 0.74102046633563379]
# 83
# 0.0225701971963
# [-0.0, -0.25447764057070055, 0.18010790726480727, -0.0, 0.11351097331023044, 0.0016078321976110011, -0.022003122086846353, 0.0, -0.3329572346772608, 0.0, -0.1571969299126991, -0.0, 0.0, 0.0, -0.0, 0.3557131557909046, -0.4959033805987955, -0.0, 0.12817407516481044, -0.44151803227239594, 0.0, 0.21694099159814012, -0.17840943728951855, -0.20224564878231013, -0.049083678768394534, -0.11650200737392888]
# 3.73367864044e-14

# %%
# select the features
boundary = 0.0001

selectedFeatures = []
data_deleted = data_pandas

for i in range(len(weights)):
    if abs(weights[i])> boundary:
        selectedFeatures.append(data_pandas.columns.values[i])
    else:
        data_deleted = data_deleted.drop(data_pandas.columns.values[i],axis=1)

# %%
# convert both to Numpy array representation
data_d = data_deleted.as_matrix()
clf = linear_model.Lasso(alpha=alpha)
clf.fit(data_d, target)
weights = clf.coef_
print(weights.tolist())
print(clf.intercept_)
data_deleted.columns
# Out:
# [-0.25446853974895, 0.1801113364542633, 0.11348696638334033, 0.001622284010588615, -0.021981444674343955, -0.33301094195462, -0.15712147928672698, 0.3557508394857228, -0.4959510743296107, 0.12817545982842335, -0.4414849457009985, 0.2169472062928381, -0.17836435425627728, -0.20225354897400427, -0.049065439549690115, -0.11653602133586757]
# 3.73368356803e-14
# Index(['GVA', 'Rainfall_perMon', 'SummerNight_ave_temperature',
#        'Sunshine_perMon', 'WinterDay_ave_temperature', 'hospitals_number',
#        'number_of_universities', 'school_number', 'stations_number',
#        'traffic_noise', 'unemployment', 'pubs_number_per_person',
#        'stations_number_per_person', 'school_number_per_person',
#        'total_jobs_per_person', 'number_of_universities_per_person'],
#       dtype='object')

# %%
from pprint import pprint

# save features to dictionary
values = weights.tolist()
keys = data_deleted.columns

count = 0
valueFeatures = {}
for key in keys:
    valueFeatures[key] = values[count]
    count += 1


sortedFeatures = sorted(valueFeatures, key=lambda dict_key: abs(valueFeatures[dict_key]))
print("The rank of importance: less to most")  
pprint(sortedFeatures)
valueFeatures
# Out:
# The rank of importance: less to most
# ['Sunshine_perMon',
#  'WinterDay_ave_temperature',
#  'total_jobs_per_person',
#  'SummerNight_ave_temperature',
#  'number_of_universities_per_person',
#  'traffic_noise',
#  'number_of_universities',
#  'stations_number_per_person',
#  'Rainfall_perMon',
#  'school_number_per_person',
#  'pubs_number_per_person',
#  'GVA',
#  'hospitals_number',
#  'school_number',
#  'unemployment',
#  'stations_number']
# {'GVA': -0.25446853974895,
#  'Rainfall_perMon': 0.1801113364542633,
#  'SummerNight_ave_temperature': 0.11348696638334033,
#  'Sunshine_perMon': 0.001622284010588615,
#  'WinterDay_ave_temperature': -0.021981444674343955,
#  'hospitals_number': -0.33301094195462,
#  'number_of_universities': -0.15712147928672698,
#  'number_of_universities_per_person': -0.11653602133586757,
#  'pubs_number_per_person': 0.2169472062928381,
#  'school_number': 0.3557508394857228,
#  'school_number_per_person': -0.20225354897400427,
#  'stations_number': -0.4959510743296107,
#  'stations_number_per_person': -0.17836435425627728,
#  'total_jobs_per_person': -0.049065439549690115,
#  'traffic_noise': 0.12817545982842335,
#  'unemployment': -0.4414849457009985}

# %% [markdown]
# ## Randomforest

# %%
from sklearn.ensemble import RandomForestRegressor
regr = RandomForestRegressor(max_depth=3, random_state=0)
regr.fit(data, target)
importance_rank_randomForest = regr.feature_importances_.tolist()
keys = list(data_pandas.columns)
randomForest_result = {}
for i in range(len(importance_rank_randomForest)):
    randomForest_result[keys[i]] = importance_rank_randomForest[i]
sortedFeatures = sorted(randomForest_result, key=lambda dict_key: abs(randomForest_result[dict_key]))
print("The rank of importance: less to most")  
pprint(sortedFeatures)
collection = db.factorsRank
collection.drop()
collection.insert_one(randomForest_result)
collection.find_one()
# Out:
# The rank of importance: less to most
# ['SummerDay_ave_temperature',
#  'SummerNight_ave_temperature',
#  'Sunshine_perMon',
#  'road_traffic_2015',
#  'traffic_noise',
#  'school_number_per_person',
#  'FrostDay_perYear',
#  'pubs_number',
#  'total_jobs_per_person',
#  'number_of_universities',
#  'total_jobs',
#  'Rainfall_perMon',
#  'stations_number_per_person',
#  'house_price',
#  'GVA',
#  'number_of_universities_per_person',
#  'WinterNight_ave_temperature',
#  'population',
#  'WinterDay_ave_temperature',
#  'pubs_number_per_person',
#  'unemployment',
#  'school_number',
#  'hospitals_number_per_person',
#  'hospitals_number',
#  'stations_number',
#  'road_traffic_2016']
# {'FrostDay_perYear': 2.8603382127892094e-05,
#  'GVA': 0.012105026105635082,
#  'Rainfall_perMon': 0.004313505494751562,
#  'SummerDay_ave_temperature': 0.0,
#  'SummerNight_ave_temperature': 0.0,
#  'Sunshine_perMon': 0.0,
#  'WinterDay_ave_temperature': 0.032802557726910396,
#  'WinterNight_ave_temperature': 0.023259177597378482,
#  '_id': ObjectId('5a4e02a57c4c7b10887dac8d'),
#  'hospitals_number': 0.13849379181378044,
#  'hospitals_number_per_person': 0.11223550170873713,
#  'house_price': 0.009815594922222743,
#  'number_of_universities': 0.0020814155846021884,
#  'number_of_universities_per_person': 0.015763443160266254,
#  'population': 0.02749113337050372,
#  'pubs_number': 4.621981803086575e-05,
#  'pubs_number_per_person': 0.052369125668876734,
#  'road_traffic_2015': 0.0,
#  'road_traffic_2016': 0.1910347576824795,
#  'school_number': 0.10026176707881813,
#  'school_number_per_person': 0.0,
#  'stations_number': 0.17258035819124543,
#  'stations_number_per_person': 0.006260976034285652,
#  'total_jobs': 0.004009982598814446,
#  'total_jobs_per_person': 0.00030544077285242147,
#  'traffic_noise': 0.0,
#  'unemployment': 0.09474162128768097}

# %% [markdown]
# ## pearsonr

# %%
from scipy.stats import pearsonr
keys = list(data_pandas.columns)
pearsonr_dict={}
for i in range(len(data[0,:])):
    p = pearsonr(data[:,i],target)
    pearsonr_dict[keys[i]] = p[0]
#     print("the %s pearsonr correlation coefficient is %f, p-value is %f " % (keys[i],p[0],p[1]))
    
collection = db.pearsonr_correlation_coefficient
collection.drop()
collection.insert_one(pearsonr_dict)
collection.find_one()
# Out:
# {'FrostDay_perYear': -0.08478424574173213,
#  'GVA': 0.06335766657536343,
#  'Rainfall_perMon': 0.11724918468174153,
#  'SummerDay_ave_temperature': 0.04341544893975856,
#  'SummerNight_ave_temperature': 0.12461221164193617,
#  'Sunshine_perMon': 0.2533101555461657,
#  'WinterDay_ave_temperature': 0.07005569541019249,
#  'WinterNight_ave_temperature': 0.1252198796967537,
#  '_id': ObjectId('5a4e02ae7c4c7b10887dac8e'),
#  'hospitals_number': -0.5012433170429345,
#  'hospitals_number_per_person': -0.1181353726020228,
#  'house_price': 0.17919337031324564,
#  'number_of_universities': -0.36488911383812395,
#  'number_of_universities_per_person': -0.18804092650624296,
#  'population': -0.3508133869562756,
#  'pubs_number': -0.2951141951151909,
#  'pubs_number_per_person': 0.02249775003958534,
#  'road_traffic_2015': -0.3366740098157766,
#  'road_traffic_2016': -0.3646765898825828,
#  'school_number': -0.28321452052594553,
#  'school_number_per_person': 0.12643461884437665,
#  'stations_number': -0.5340162039504348,
#  'stations_number_per_person': -0.21616129491596672,
#  'total_jobs': -0.33976888607386735,
#  'total_jobs_per_person': 0.11133198987060415,
#  'traffic_noise': -0.2526740060996267,
#  'unemployment': -0.35940800368180936}

# %%
for i in range(len(data[0,:])):
    for j in range(len(data[0,:])):
        p = pearsonr(data[:,i],data[:,j])
        print("the %s and %s pearsonr correlation coefficient is %f, p-value is %f " % (keys[i],keys[j],p[0],p[1]))
# Out:
# the FrostDay_perYear and FrostDay_perYear pearsonr correlation coefficient is 1.000000, p-value is 0.000000
# the FrostDay_perYear and GVA pearsonr correlation coefficient is -0.128693, p-value is 0.243341
# the FrostDay_perYear and Rainfall_perMon pearsonr correlation coefficient is 0.064880, p-value is 0.557642
# the FrostDay_perYear and SummerDay_ave_temperature pearsonr correlation coefficient is -0.315916, p-value is 0.003418
# the FrostDay_perYear and SummerNight_ave_temperature pearsonr correlation coefficient is -0.810783, p-value is 0.000000
# the FrostDay_perYear and Sunshine_perMon pearsonr correlation coefficient is -0.388298, p-value is 0.000262
# the FrostDay_perYear and WinterDay_ave_temperature pearsonr correlation coefficient is -0.081161, p-value is 0.462997
# the FrostDay_perYear and WinterNight_ave_temperature pearsonr correlation coefficient is -0.926359, p-value is 0.000000
# the FrostDay_perYear and hospitals_number pearsonr correlation coefficient is 0.182725, p-value is 0.096182
# the FrostDay_perYear and house_price pearsonr correlation coefficient is -0.226442, p-value is 0.038334
# the FrostDay_perYear and number_of_universities pearsonr correlation coefficient is 0.158841, p-value is 0.148974
# the FrostDay_perYear and population pearsonr correlation coefficient is 0.073343, p-value is 0.507316
# the FrostDay_perYear and pubs_number pearsonr correlation coefficient is 0.075129, p-value is 0.497004
# the FrostDay_perYear and road_traffic_2015 pearsonr correlation coefficient is 0.361189, p-value is 0.000737
# the FrostDay_perYear and road_traffic_2016 pearsonr correlation coefficient is 0.367317, p-value is 0.000588
# the FrostDay_perYear and school_number pearsonr correlation coefficient is 0.012214, p-value is 0.912192
# the FrostDay_perYear and stations_number pearsonr correlation coefficient is 0.081274, p-value is 0.462372
# the FrostDay_perYear and total_jobs pearsonr correlation coefficient is 0.080671, p-value is 0.465714
# the FrostDay_perYear and traffic_noise pearsonr correlation coefficient is -0.008940, p-value is 0.935674
# the FrostDay_perYear and unemployment pearsonr correlation coefficient is -0.092831, p-value is 0.400975
# the FrostDay_perYear and hospitals_number_per_person pearsonr correlation coefficient is -0.024339, p-value is 0.826057
# the FrostDay_perYear and pubs_number_per_person pearsonr correlation coefficient is -0.031337, p-value is 0.777196
# the FrostDay_perYear and stations_number_per_person pearsonr correlation coefficient is -0.139405, p-value is 0.205977
# the FrostDay_perYear and school_number_per_person pearsonr correlation coefficient is -0.224415, p-value is 0.040147
# the FrostDay_perYear and total_jobs_per_person pearsonr correlation coefficient is -0.002654, p-value is 0.980882
# the FrostDay_perYear and number_of_universities_per_person pearsonr correlation coefficient is 0.047760, p-value is 0.666169
# the GVA and FrostDay_perYear pearsonr correlation coefficient is -0.128693, p-value is 0.243341
# the GVA and GVA pearsonr correlation coefficient is 1.000000, p-value is 0.000000
# the GVA and Rainfall_perMon pearsonr correlation coefficient is -0.437382, p-value is 0.000032
# the GVA and SummerDay_ave_temperature pearsonr correlation coefficient is 0.724659, p-value is 0.000000
# the GVA and SummerNight_ave_temperature pearsonr correlation coefficient is 0.503303, p-value is 0.000001
# the GVA and Sunshine_perMon pearsonr correlation coefficient is 0.520431, p-value is 0.000000
# the GVA and WinterDay_ave_temperature pearsonr correlation coefficient is 0.687081, p-value is 0.000000
# the GVA and WinterNight_ave_temperature pearsonr correlation coefficient is 0.306321, p-value is 0.004599
# the GVA and hospitals_number pearsonr correlation coefficient is -0.244811, p-value is 0.024808
# the GVA and house_price pearsonr correlation coefficient is 0.767735, p-value is 0.000000
# the GVA and number_of_universities pearsonr correlation coefficient is -0.297881, p-value is 0.005923
# the GVA and population pearsonr correlation coefficient is -0.234764, p-value is 0.031591
# the GVA and pubs_number pearsonr correlation coefficient is -0.397469, p-value is 0.000181
# the GVA and road_traffic_2015 pearsonr correlation coefficient is -0.213280, p-value is 0.051423
# the GVA and road_traffic_2016 pearsonr correlation coefficient is -0.171795, p-value is 0.118153
# the GVA and school_number pearsonr correlation coefficient is -0.167898, p-value is 0.126856
# the GVA and stations_number pearsonr correlation coefficient is -0.338628, p-value is 0.001629
# the GVA and total_jobs pearsonr correlation coefficient is -0.160740, p-value is 0.144112
# the GVA and traffic_noise pearsonr correlation coefficient is -0.366279, p-value is 0.000611
# the GVA and unemployment pearsonr correlation coefficient is -0.660717, p-value is 0.000000
# the GVA and hospitals_number_per_person pearsonr correlation coefficient is 0.005734, p-value is 0.958717
# the GVA and pubs_number_per_person pearsonr correlation coefficient is -0.374692, p-value is 0.000446
# the GVA and stations_number_per_person pearsonr correlation coefficient is -0.181309, p-value is 0.098834
# the GVA and school_number_per_person pearsonr correlation coefficient is 0.242396, p-value is 0.026314
# the GVA and total_jobs_per_person pearsonr correlation coefficient is 0.587183, p-value is 0.000000
# the GVA and number_of_universities_per_person pearsonr correlation coefficient is -0.187233, p-value is 0.088116
# the Rainfall_perMon and FrostDay_perYear pearsonr correlation coefficient is 0.064880, p-value is 0.557642
# the Rainfall_perMon and GVA pearsonr correlation coefficient is -0.437382, p-value is 0.000032
# the Rainfall_perMon and Rainfall_perMon pearsonr correlation coefficient is 1.000000, p-value is 0.000000
# the Rainfall_perMon and SummerDay_ave_temperature pearsonr correlation coefficient is -0.783934, p-value is 0.000000
# the Rainfall_perMon and SummerNight_ave_temperature pearsonr correlation coefficient is -0.407884, p-value is 0.000118
# the Rainfall_perMon and Sunshine_perMon pearsonr correlation coefficient is -0.425532, p-value is 0.000055
# the Rainfall_perMon and WinterDay_ave_temperature pearsonr correlation coefficient is -0.584798, p-value is 0.000000
# the Rainfall_perMon and WinterNight_ave_temperature pearsonr correlation coefficient is -0.194284, p-value is 0.076580
# the Rainfall_perMon and hospitals_number pearsonr correlation coefficient is 0.227691, p-value is 0.037251
# the Rainfall_perMon and house_price pearsonr correlation coefficient is -0.439973, p-value is 0.000028
# the Rainfall_perMon and number_of_universities pearsonr correlation coefficient is 0.267697, p-value is 0.013823
# the Rainfall_perMon and population pearsonr correlation coefficient is 0.165111, p-value is 0.133379
# the Rainfall_perMon and pubs_number pearsonr correlation coefficient is 0.524227, p-value is 0.000000
# the Rainfall_perMon and road_traffic_2015 pearsonr correlation coefficient is 0.132145, p-value is 0.230822
# the Rainfall_perMon and road_traffic_2016 pearsonr correlation coefficient is 0.118709, p-value is 0.282155
# the Rainfall_perMon and school_number pearsonr correlation coefficient is 0.066548, p-value is 0.547538
# the Rainfall_perMon and stations_number pearsonr correlation coefficient is 0.250291, p-value is 0.021661
# the Rainfall_perMon and total_jobs pearsonr correlation coefficient is 0.164224, p-value is 0.135506
# the Rainfall_perMon and traffic_noise pearsonr correlation coefficient is 0.480994, p-value is 0.000004
# the Rainfall_perMon and unemployment pearsonr correlation coefficient is 0.259624, p-value is 0.017084
# the Rainfall_perMon and hospitals_number_per_person pearsonr correlation coefficient is -0.057829, p-value is 0.601317
# the Rainfall_perMon and pubs_number_per_person pearsonr correlation coefficient is 0.329038, p-value is 0.002243
# the Rainfall_perMon and stations_number_per_person pearsonr correlation coefficient is 0.154082, p-value is 0.161693
# the Rainfall_perMon and school_number_per_person pearsonr correlation coefficient is -0.311631, p-value is 0.003907
# the Rainfall_perMon and total_jobs_per_person pearsonr correlation coefficient is -0.312980, p-value is 0.003747
# the Rainfall_perMon and number_of_universities_per_person pearsonr correlation coefficient is 0.116573, p-value is 0.290967
# the SummerDay_ave_temperature and FrostDay_perYear pearsonr correlation coefficient is -0.315916, p-value is 0.003418
# the SummerDay_ave_temperature and GVA pearsonr correlation coefficient is 0.724659, p-value is 0.000000
# the SummerDay_ave_temperature and Rainfall_perMon pearsonr correlation coefficient is -0.783934, p-value is 0.000000
# the SummerDay_ave_temperature and SummerDay_ave_temperature pearsonr correlation coefficient is 1.000000, p-value is 0.000000
# the SummerDay_ave_temperature and SummerNight_ave_temperature pearsonr correlation coefficient is 0.720351, p-value is 0.000000
# the SummerDay_ave_temperature and Sunshine_perMon pearsonr correlation coefficient is 0.649877, p-value is 0.000000
# the SummerDay_ave_temperature and WinterDay_ave_temperature pearsonr correlation coefficient is 0.828657, p-value is 0.000000
# the SummerDay_ave_temperature and WinterNight_ave_temperature pearsonr correlation coefficient is 0.511657, p-value is 0.000001
# the SummerDay_ave_temperature and hospitals_number pearsonr correlation coefficient is -0.411409, p-value is 0.000101
# the SummerDay_ave_temperature and house_price pearsonr correlation coefficient is 0.715205, p-value is 0.000000
# the SummerDay_ave_temperature and number_of_universities pearsonr correlation coefficient is -0.405515, p-value is 0.000130
# the SummerDay_ave_temperature and population pearsonr correlation coefficient is -0.284169, p-value is 0.008801
# the SummerDay_ave_temperature and pubs_number pearsonr correlation coefficient is -0.652788, p-value is 0.000000
# the SummerDay_ave_temperature and road_traffic_2015 pearsonr correlation coefficient is -0.261419, p-value is 0.016307
# the SummerDay_ave_temperature and road_traffic_2016 pearsonr correlation coefficient is -0.236944, p-value is 0.030000
# the SummerDay_ave_temperature and school_number pearsonr correlation coefficient is -0.207363, p-value is 0.058403
# the SummerDay_ave_temperature and stations_number pearsonr correlation coefficient is -0.419063, p-value is 0.000073
# the SummerDay_ave_temperature and total_jobs pearsonr correlation coefficient is -0.269230, p-value is 0.013269
# the SummerDay_ave_temperature and traffic_noise pearsonr correlation coefficient is -0.540314, p-value is 0.000000
# the SummerDay_ave_temperature and unemployment pearsonr correlation coefficient is -0.437330, p-value is 0.000032
# the SummerDay_ave_temperature and hospitals_number_per_person pearsonr correlation coefficient is -0.035074, p-value is 0.751442
# the SummerDay_ave_temperature and pubs_number_per_person pearsonr correlation coefficient is -0.493210, p-value is 0.000002
# the SummerDay_ave_temperature and stations_number_per_person pearsonr correlation coefficient is -0.198319, p-value is 0.070545
# the SummerDay_ave_temperature and school_number_per_person pearsonr correlation coefficient is 0.309320, p-value is 0.004196
# the SummerDay_ave_temperature and total_jobs_per_person pearsonr correlation coefficient is 0.432943, p-value is 0.000039
# the SummerDay_ave_temperature and number_of_universities_per_person pearsonr correlation coefficient is -0.161566, p-value is 0.142034
# the SummerNight_ave_temperature and FrostDay_perYear pearsonr correlation coefficient is -0.810783, p-value is 0.000000
# the SummerNight_ave_temperature and GVA pearsonr correlation coefficient is 0.503303, p-value is 0.000001
# the SummerNight_ave_temperature and Rainfall_perMon pearsonr correlation coefficient is -0.407884, p-value is 0.000118
# the SummerNight_ave_temperature and SummerDay_ave_temperature pearsonr correlation coefficient is 0.720351, p-value is 0.000000
# the SummerNight_ave_temperature and SummerNight_ave_temperature pearsonr correlation coefficient is 1.000000, p-value is 0.000000
# the SummerNight_ave_temperature and Sunshine_perMon pearsonr correlation coefficient is 0.643703, p-value is 0.000000
# the SummerNight_ave_temperature and WinterDay_ave_temperature pearsonr correlation coefficient is 0.594114, p-value is 0.000000
# the SummerNight_ave_temperature and WinterNight_ave_temperature pearsonr correlation coefficient is 0.918571, p-value is 0.000000
# the SummerNight_ave_temperature and hospitals_number pearsonr correlation coefficient is -0.319749, p-value is 0.003028
# the SummerNight_ave_temperature and house_price pearsonr correlation coefficient is 0.607043, p-value is 0.000000
# the SummerNight_ave_temperature and number_of_universities pearsonr correlation coefficient is -0.341823, p-value is 0.001461
# the SummerNight_ave_temperature and population pearsonr correlation coefficient is -0.261417, p-value is 0.016308
# the SummerNight_ave_temperature and pubs_number pearsonr correlation coefficient is -0.414547, p-value is 0.000088
# the SummerNight_ave_temperature and road_traffic_2015 pearsonr correlation coefficient is -0.390925, p-value is 0.000236
# the SummerNight_ave_temperature and road_traffic_2016 pearsonr correlation coefficient is -0.371349, p-value is 0.000506
# the SummerNight_ave_temperature and school_number pearsonr correlation coefficient is -0.191100, p-value is 0.081630
# the SummerNight_ave_temperature and stations_number pearsonr correlation coefficient is -0.304755, p-value is 0.004822
# the SummerNight_ave_temperature and total_jobs pearsonr correlation coefficient is -0.250432, p-value is 0.021585
# the SummerNight_ave_temperature and traffic_noise pearsonr correlation coefficient is -0.299944, p-value is 0.005572
# the SummerNight_ave_temperature and unemployment pearsonr correlation coefficient is -0.278121, p-value is 0.010420
# the SummerNight_ave_temperature and hospitals_number_per_person pearsonr correlation coefficient is 0.175514, p-value is 0.110282
# the SummerNight_ave_temperature and pubs_number_per_person pearsonr correlation coefficient is -0.221981, p-value is 0.042417
# the SummerNight_ave_temperature and stations_number_per_person pearsonr correlation coefficient is 0.052282, p-value is 0.636701
# the SummerNight_ave_temperature and school_number_per_person pearsonr correlation coefficient is 0.329241, p-value is 0.002228
# the SummerNight_ave_temperature and total_jobs_per_person pearsonr correlation coefficient is 0.289120, p-value is 0.007645
# the SummerNight_ave_temperature and number_of_universities_per_person pearsonr correlation coefficient is -0.108709, p-value is 0.324956
# the Sunshine_perMon and FrostDay_perYear pearsonr correlation coefficient is -0.388298, p-value is 0.000262
# the Sunshine_perMon and GVA pearsonr correlation coefficient is 0.520431, p-value is 0.000000
# the Sunshine_perMon and Rainfall_perMon pearsonr correlation coefficient is -0.425532, p-value is 0.000055
# the Sunshine_perMon and SummerDay_ave_temperature pearsonr correlation coefficient is 0.649877, p-value is 0.000000
# the Sunshine_perMon and SummerNight_ave_temperature pearsonr correlation coefficient is 0.643703, p-value is 0.000000
# the Sunshine_perMon and Sunshine_perMon pearsonr correlation coefficient is 1.000000, p-value is 0.000000
# the Sunshine_perMon and WinterDay_ave_temperature pearsonr correlation coefficient is 0.658146, p-value is 0.000000
# the Sunshine_perMon and WinterNight_ave_temperature pearsonr correlation coefficient is 0.603905, p-value is 0.000000
# the Sunshine_perMon and hospitals_number pearsonr correlation coefficient is -0.424035, p-value is 0.000058
# the Sunshine_perMon and house_price pearsonr correlation coefficient is 0.617108, p-value is 0.000000
# the Sunshine_perMon and number_of_universities pearsonr correlation coefficient is -0.438491, p-value is 0.000030
# the Sunshine_perMon and population pearsonr correlation coefficient is -0.340634, p-value is 0.001521
# the Sunshine_perMon and pubs_number pearsonr correlation coefficient is -0.669798, p-value is 0.000000
# the Sunshine_perMon and road_traffic_2015 pearsonr correlation coefficient is -0.402147, p-value is 0.000149
# the Sunshine_perMon and road_traffic_2016 pearsonr correlation coefficient is -0.391461, p-value is 0.000231
# the Sunshine_perMon and school_number pearsonr correlation coefficient is -0.246052, p-value is 0.024063
# the Sunshine_perMon and stations_number pearsonr correlation coefficient is -0.502436, p-value is 0.000001
# the Sunshine_perMon and total_jobs pearsonr correlation coefficient is -0.339600, p-value is 0.001576
# the Sunshine_perMon and traffic_noise pearsonr correlation coefficient is -0.508385, p-value is 0.000001
# the Sunshine_perMon and unemployment pearsonr correlation coefficient is -0.470423, p-value is 0.000006
# the Sunshine_perMon and hospitals_number_per_person pearsonr correlation coefficient is 0.121520, p-value is 0.270834
# the Sunshine_perMon and pubs_number_per_person pearsonr correlation coefficient is -0.412237, p-value is 0.000098
# the Sunshine_perMon and stations_number_per_person pearsonr correlation coefficient is -0.190133, p-value is 0.083216
# the Sunshine_perMon and school_number_per_person pearsonr correlation coefficient is 0.415478, p-value is 0.000085
# the Sunshine_perMon and total_jobs_per_person pearsonr correlation coefficient is 0.260273, p-value is 0.016799
# the Sunshine_perMon and number_of_universities_per_person pearsonr correlation coefficient is -0.151527, p-value is 0.168846
# the WinterDay_ave_temperature and FrostDay_perYear pearsonr correlation coefficient is -0.081161, p-value is 0.462997
# the WinterDay_ave_temperature and GVA pearsonr correlation coefficient is 0.687081, p-value is 0.000000
# the WinterDay_ave_temperature and Rainfall_perMon pearsonr correlation coefficient is -0.584798, p-value is 0.000000
# the WinterDay_ave_temperature and SummerDay_ave_temperature pearsonr correlation coefficient is 0.828657, p-value is 0.000000
# the WinterDay_ave_temperature and SummerNight_ave_temperature pearsonr correlation coefficient is 0.594114, p-value is 0.000000
# the WinterDay_ave_temperature and Sunshine_perMon pearsonr correlation coefficient is 0.658146, p-value is 0.000000
# the WinterDay_ave_temperature and WinterDay_ave_temperature pearsonr correlation coefficient is 1.000000, p-value is 0.000000
# the WinterDay_ave_temperature and WinterNight_ave_temperature pearsonr correlation coefficient is 0.421439, p-value is 0.000065
# the WinterDay_ave_temperature and hospitals_number pearsonr correlation coefficient is -0.361855, p-value is 0.000719
# the WinterDay_ave_temperature and house_price pearsonr correlation coefficient is 0.760998, p-value is 0.000000
# the WinterDay_ave_temperature and number_of_universities pearsonr correlation coefficient is -0.376450, p-value is 0.000417
# the WinterDay_ave_temperature and population pearsonr correlation coefficient is -0.345143, p-value is 0.001303
# the WinterDay_ave_temperature and pubs_number pearsonr correlation coefficient is -0.684927, p-value is 0.000000
# the WinterDay_ave_temperature and road_traffic_2015 pearsonr correlation coefficient is -0.219184, p-value is 0.045158
# the WinterDay_ave_temperature and road_traffic_2016 pearsonr correlation coefficient is -0.191852, p-value is 0.080414
# the WinterDay_ave_temperature and school_number pearsonr correlation coefficient is -0.303688, p-value is 0.004980
# the WinterDay_ave_temperature and stations_number pearsonr correlation coefficient is -0.431517, p-value is 0.000042
# the WinterDay_ave_temperature and total_jobs pearsonr correlation coefficient is -0.323502, p-value is 0.002685
# the WinterDay_ave_temperature and traffic_noise pearsonr correlation coefficient is -0.578001, p-value is 0.000000
# the WinterDay_ave_temperature and unemployment pearsonr correlation coefficient is -0.636609, p-value is 0.000000
# the WinterDay_ave_temperature and hospitals_number_per_person pearsonr correlation coefficient is 0.236436, p-value is 0.030365
# the WinterDay_ave_temperature and pubs_number_per_person pearsonr correlation coefficient is -0.430959, p-value is 0.000043
# the WinterDay_ave_temperature and stations_number_per_person pearsonr correlation coefficient is -0.060566, p-value is 0.584184
# the WinterDay_ave_temperature and school_number_per_person pearsonr correlation coefficient is 0.304829, p-value is 0.004812
# the WinterDay_ave_temperature and total_jobs_per_person pearsonr correlation coefficient is 0.521375, p-value is 0.000000
# the WinterDay_ave_temperature and number_of_universities_per_person pearsonr correlation coefficient is -0.031174, p-value is 0.778323
# the WinterNight_ave_temperature and FrostDay_perYear pearsonr correlation coefficient is -0.926359, p-value is 0.000000
# the WinterNight_ave_temperature and GVA pearsonr correlation coefficient is 0.306321, p-value is 0.004599
# the WinterNight_ave_temperature and Rainfall_perMon pearsonr correlation coefficient is -0.194284, p-value is 0.076580
# the WinterNight_ave_temperature and SummerDay_ave_temperature pearsonr correlation coefficient is 0.511657, p-value is 0.000001
# the WinterNight_ave_temperature and SummerNight_ave_temperature pearsonr correlation coefficient is 0.918571, p-value is 0.000000
# the WinterNight_ave_temperature and Sunshine_perMon pearsonr correlation coefficient is 0.603905, p-value is 0.000000
# the WinterNight_ave_temperature and WinterDay_ave_temperature pearsonr correlation coefficient is 0.421439, p-value is 0.000065
# the WinterNight_ave_temperature and WinterNight_ave_temperature pearsonr correlation coefficient is 1.000000, p-value is 0.000000
# the WinterNight_ave_temperature and hospitals_number pearsonr correlation coefficient is -0.274442, p-value is 0.011526
# the WinterNight_ave_temperature and house_price pearsonr correlation coefficient is 0.449844, p-value is 0.000018
# the WinterNight_ave_temperature and number_of_universities pearsonr correlation coefficient is -0.245425, p-value is 0.024437
# the WinterNight_ave_temperature and population pearsonr correlation coefficient is -0.173028, p-value is 0.115495
# the WinterNight_ave_temperature and pubs_number pearsonr correlation coefficient is -0.301768, p-value is 0.005276
# the WinterNight_ave_temperature and road_traffic_2015 pearsonr correlation coefficient is -0.396662, p-value is 0.000187
# the WinterNight_ave_temperature and road_traffic_2016 pearsonr correlation coefficient is -0.396118, p-value is 0.000192
# the WinterNight_ave_temperature and school_number pearsonr correlation coefficient is -0.107816, p-value is 0.328968
# the WinterNight_ave_temperature and stations_number pearsonr correlation coefficient is -0.220293, p-value is 0.044054
# the WinterNight_ave_temperature and total_jobs pearsonr correlation coefficient is -0.175717, p-value is 0.109863
# the WinterNight_ave_temperature and traffic_noise pearsonr correlation coefficient is -0.174015, p-value is 0.113402
# the WinterNight_ave_temperature and unemployment pearsonr correlation coefficient is -0.141473, p-value is 0.199262
# the WinterNight_ave_temperature and hospitals_number_per_person pearsonr correlation coefficient is 0.149563, p-value is 0.174501
# the WinterNight_ave_temperature and pubs_number_per_person pearsonr correlation coefficient is -0.115249, p-value is 0.296519
# the WinterNight_ave_temperature and stations_number_per_person pearsonr correlation coefficient is 0.118623, p-value is 0.282507
# the WinterNight_ave_temperature and school_number_per_person pearsonr correlation coefficient is 0.310664, p-value is 0.004026
# the WinterNight_ave_temperature and total_jobs_per_person pearsonr correlation coefficient is 0.160286, p-value is 0.145262
# the WinterNight_ave_temperature and number_of_universities_per_person pearsonr correlation coefficient is -0.009767, p-value is 0.929735
# the hospitals_number and FrostDay_perYear pearsonr correlation coefficient is 0.182725, p-value is 0.096182
# the hospitals_number and GVA pearsonr correlation coefficient is -0.244811, p-value is 0.024808
# the hospitals_number and Rainfall_perMon pearsonr correlation coefficient is 0.227691, p-value is 0.037251
# the hospitals_number and SummerDay_ave_temperature pearsonr correlation coefficient is -0.411409, p-value is 0.000101
# the hospitals_number and SummerNight_ave_temperature pearsonr correlation coefficient is -0.319749, p-value is 0.003028
# the hospitals_number and Sunshine_perMon pearsonr correlation coefficient is -0.424035, p-value is 0.000058
# the hospitals_number and WinterDay_ave_temperature pearsonr correlation coefficient is -0.361855, p-value is 0.000719
# the hospitals_number and WinterNight_ave_temperature pearsonr correlation coefficient is -0.274442, p-value is 0.011526
# the hospitals_number and hospitals_number pearsonr correlation coefficient is 1.000000, p-value is 0.000000
# the hospitals_number and house_price pearsonr correlation coefficient is -0.305696, p-value is 0.004687
# the hospitals_number and number_of_universities pearsonr correlation coefficient is 0.779043, p-value is 0.000000
# the hospitals_number and population pearsonr correlation coefficient is 0.726583, p-value is 0.000000
# the hospitals_number and pubs_number pearsonr correlation coefficient is 0.681846, p-value is 0.000000
# the hospitals_number and road_traffic_2015 pearsonr correlation coefficient is 0.583169, p-value is 0.000000
# the hospitals_number and road_traffic_2016 pearsonr correlation coefficient is 0.580187, p-value is 0.000000
# the hospitals_number and school_number pearsonr correlation coefficient is 0.739010, p-value is 0.000000
# the hospitals_number and stations_number pearsonr correlation coefficient is 0.618720, p-value is 0.000000
# the hospitals_number and total_jobs pearsonr correlation coefficient is 0.752982, p-value is 0.000000
# the hospitals_number and traffic_noise pearsonr correlation coefficient is 0.631575, p-value is 0.000000
# the hospitals_number and unemployment pearsonr correlation coefficient is 0.354269, p-value is 0.000946
# the hospitals_number and hospitals_number_per_person pearsonr correlation coefficient is 0.305746, p-value is 0.004680
# the hospitals_number and pubs_number_per_person pearsonr correlation coefficient is 0.018754, p-value is 0.865540
# the hospitals_number and stations_number_per_person pearsonr correlation coefficient is -0.089147, p-value is 0.420008
# the hospitals_number and school_number_per_person pearsonr correlation coefficient is -0.186655, p-value is 0.089118
# the hospitals_number and total_jobs_per_person pearsonr correlation coefficient is -0.052740, p-value is 0.633745
# the hospitals_number and number_of_universities_per_person pearsonr correlation coefficient is 0.330241, p-value is 0.002156
# the house_price and FrostDay_perYear pearsonr correlation coefficient is -0.226442, p-value is 0.038334
# the house_price and GVA pearsonr correlation coefficient is 0.767735, p-value is 0.000000
# the house_price and Rainfall_perMon pearsonr correlation coefficient is -0.439973, p-value is 0.000028
# the house_price and SummerDay_ave_temperature pearsonr correlation coefficient is 0.715205, p-value is 0.000000
# the house_price and SummerNight_ave_temperature pearsonr correlation coefficient is 0.607043, p-value is 0.000000
# the house_price and Sunshine_perMon pearsonr correlation coefficient is 0.617108, p-value is 0.000000
# the house_price and WinterDay_ave_temperature pearsonr correlation coefficient is 0.760998, p-value is 0.000000
# the house_price and WinterNight_ave_temperature pearsonr correlation coefficient is 0.449844, p-value is 0.000018
# the house_price and hospitals_number pearsonr correlation coefficient is -0.305696, p-value is 0.004687
# the house_price and house_price pearsonr correlation coefficient is 1.000000, p-value is 0.000000
# the house_price and number_of_universities pearsonr correlation coefficient is -0.230758, p-value is 0.034701
# the house_price and population pearsonr correlation coefficient is -0.284419, p-value is 0.008740
# the house_price and pubs_number pearsonr correlation coefficient is -0.516711, p-value is 0.000000
# the house_price and road_traffic_2015 pearsonr correlation coefficient is -0.305893, p-value is 0.004659
# the house_price and road_traffic_2016 pearsonr correlation coefficient is -0.272296, p-value is 0.012218
# the house_price and school_number pearsonr correlation coefficient is -0.251881, p-value is 0.020814
# the house_price and stations_number pearsonr correlation coefficient is -0.440073, p-value is 0.000028
# the house_price and total_jobs pearsonr correlation coefficient is -0.218967, p-value is 0.045376
# the house_price and traffic_noise pearsonr correlation coefficient is -0.392508, p-value is 0.000222
# the house_price and unemployment pearsonr correlation coefficient is -0.751156, p-value is 0.000000
# the house_price and hospitals_number_per_person pearsonr correlation coefficient is 0.219516, p-value is 0.044825
# the house_price and pubs_number_per_person pearsonr correlation coefficient is -0.384126, p-value is 0.000309
# the house_price and stations_number_per_person pearsonr correlation coefficient is -0.143259, p-value is 0.193589
# the house_price and school_number_per_person pearsonr correlation coefficient is 0.254046, p-value is 0.019707
# the house_price and total_jobs_per_person pearsonr correlation coefficient is 0.701414, p-value is 0.000000
# the house_price and number_of_universities_per_person pearsonr correlation coefficient is 0.115900, p-value is 0.293777
# the number_of_universities and FrostDay_perYear pearsonr correlation coefficient is 0.158841, p-value is 0.148974
# the number_of_universities and GVA pearsonr correlation coefficient is -0.297881, p-value is 0.005923
# the number_of_universities and Rainfall_perMon pearsonr correlation coefficient is 0.267697, p-value is 0.013823
# the number_of_universities and SummerDay_ave_temperature pearsonr correlation coefficient is -0.405515, p-value is 0.000130
# the number_of_universities and SummerNight_ave_temperature pearsonr correlation coefficient is -0.341823, p-value is 0.001461
# the number_of_universities and Sunshine_perMon pearsonr correlation coefficient is -0.438491, p-value is 0.000030
# the number_of_universities and WinterDay_ave_temperature pearsonr correlation coefficient is -0.376450, p-value is 0.000417
# the number_of_universities and WinterNight_ave_temperature pearsonr correlation coefficient is -0.245425, p-value is 0.024437
# the number_of_universities and hospitals_number pearsonr correlation coefficient is 0.779043, p-value is 0.000000
# the number_of_universities and house_price pearsonr correlation coefficient is -0.230758, p-value is 0.034701
# the number_of_universities and number_of_universities pearsonr correlation coefficient is 1.000000, p-value is 0.000000
# the number_of_universities and population pearsonr correlation coefficient is 0.662404, p-value is 0.000000
# the number_of_universities and pubs_number pearsonr correlation coefficient is 0.658801, p-value is 0.000000
# the number_of_universities and road_traffic_2015 pearsonr correlation coefficient is 0.578448, p-value is 0.000000
# the number_of_universities and road_traffic_2016 pearsonr correlation coefficient is 0.567994, p-value is 0.000000
# the number_of_universities and school_number pearsonr correlation coefficient is 0.606420, p-value is 0.000000
# the number_of_universities and stations_number pearsonr correlation coefficient is 0.414302, p-value is 0.000089
# the number_of_universities and total_jobs pearsonr correlation coefficient is 0.700242, p-value is 0.000000
# the number_of_universities and traffic_noise pearsonr correlation coefficient is 0.608294, p-value is 0.000000
# the number_of_universities and unemployment pearsonr correlation coefficient is 0.286138, p-value is 0.008324
# the number_of_universities and hospitals_number_per_person pearsonr correlation coefficient is 0.078931, p-value is 0.475417
# the number_of_universities and pubs_number_per_person pearsonr correlation coefficient is -0.028760, p-value is 0.795098
# the number_of_universities and stations_number_per_person pearsonr correlation coefficient is -0.281884, p-value is 0.009385
# the number_of_universities and school_number_per_person pearsonr correlation coefficient is -0.261327, p-value is 0.016346
# the number_of_universities and total_jobs_per_person pearsonr correlation coefficient is -0.064488, p-value is 0.560034
# the number_of_universities and number_of_universities_per_person pearsonr correlation coefficient is 0.690869, p-value is 0.000000
# the population and FrostDay_perYear pearsonr correlation coefficient is 0.073343, p-value is 0.507316
# the population and GVA pearsonr correlation coefficient is -0.234764, p-value is 0.031591
# the population and Rainfall_perMon pearsonr correlation coefficient is 0.165111, p-value is 0.133379
# the population and SummerDay_ave_temperature pearsonr correlation coefficient is -0.284169, p-value is 0.008801
# the population and SummerNight_ave_temperature pearsonr correlation coefficient is -0.261417, p-value is 0.016308
# the population and Sunshine_perMon pearsonr correlation coefficient is -0.340634, p-value is 0.001521
# the population and WinterDay_ave_temperature pearsonr correlation coefficient is -0.345143, p-value is 0.001303
# the population and WinterNight_ave_temperature pearsonr correlation coefficient is -0.173028, p-value is 0.115495
# the population and hospitals_number pearsonr correlation coefficient is 0.726583, p-value is 0.000000
# the population and house_price pearsonr correlation coefficient is -0.284419, p-value is 0.008740
# the population and number_of_universities pearsonr correlation coefficient is 0.662404, p-value is 0.000000
# the population and population pearsonr correlation coefficient is 1.000000, p-value is 0.000000
# the population and pubs_number pearsonr correlation coefficient is 0.546639, p-value is 0.000000
# the population and road_traffic_2015 pearsonr correlation coefficient is 0.510170, p-value is 0.000001
# the population and road_traffic_2016 pearsonr correlation coefficient is 0.498474, p-value is 0.000001
# the population and school_number pearsonr correlation coefficient is 0.810281, p-value is 0.000000
# the population and stations_number pearsonr correlation coefficient is 0.686357, p-value is 0.000000
# the population and total_jobs pearsonr correlation coefficient is 0.985825, p-value is 0.000000
# the population and traffic_noise pearsonr correlation coefficient is 0.778560, p-value is 0.000000
# the population and unemployment pearsonr correlation coefficient is 0.375785, p-value is 0.000427
# the population and hospitals_number_per_person pearsonr correlation coefficient is -0.198825, p-value is 0.069816
# the population and pubs_number_per_person pearsonr correlation coefficient is -0.203885, p-value is 0.062853
# the population and stations_number_per_person pearsonr correlation coefficient is -0.170241, p-value is 0.121568
# the population and school_number_per_person pearsonr correlation coefficient is -0.374345, p-value is 0.000452
# the population and total_jobs_per_person pearsonr correlation coefficient is -0.218554, p-value is 0.045795
# the population and number_of_universities_per_person pearsonr correlation coefficient is 0.108700, p-value is 0.324996
# the pubs_number and FrostDay_perYear pearsonr correlation coefficient is 0.075129, p-value is 0.497004
# the pubs_number and GVA pearsonr correlation coefficient is -0.397469, p-value is 0.000181
# the pubs_number and Rainfall_perMon pearsonr correlation coefficient is 0.524227, p-value is 0.000000
# the pubs_number and SummerDay_ave_temperature pearsonr correlation coefficient is -0.652788, p-value is 0.000000
# the pubs_number and SummerNight_ave_temperature pearsonr correlation coefficient is -0.414547, p-value is 0.000088
# the pubs_number and Sunshine_perMon pearsonr correlation coefficient is -0.669798, p-value is 0.000000
# the pubs_number and WinterDay_ave_temperature pearsonr correlation coefficient is -0.684927, p-value is 0.000000
# the pubs_number and WinterNight_ave_temperature pearsonr correlation coefficient is -0.301768, p-value is 0.005276
# the pubs_number and hospitals_number pearsonr correlation coefficient is 0.681846, p-value is 0.000000
# the pubs_number and house_price pearsonr correlation coefficient is -0.516711, p-value is 0.000000
# the pubs_number and number_of_universities pearsonr correlation coefficient is 0.658801, p-value is 0.000000
# the pubs_number and population pearsonr correlation coefficient is 0.546639, p-value is 0.000000
# the pubs_number and pubs_number pearsonr correlation coefficient is 1.000000, p-value is 0.000000
# the pubs_number and road_traffic_2015 pearsonr correlation coefficient is 0.348666, p-value is 0.001153
# the pubs_number and road_traffic_2016 pearsonr correlation coefficient is 0.336809, p-value is 0.001732
# the pubs_number and school_number pearsonr correlation coefficient is 0.528952, p-value is 0.000000
# the pubs_number and stations_number pearsonr correlation coefficient is 0.703822, p-value is 0.000000
# the pubs_number and total_jobs pearsonr correlation coefficient is 0.575563, p-value is 0.000000
# the pubs_number and traffic_noise pearsonr correlation coefficient is 0.748980, p-value is 0.000000
# the pubs_number and unemployment pearsonr correlation coefficient is 0.507712, p-value is 0.000001
# the pubs_number and hospitals_number_per_person pearsonr correlation coefficient is -0.078207, p-value is 0.479491
# the pubs_number and pubs_number_per_person pearsonr correlation coefficient is 0.518157, p-value is 0.000000
# the pubs_number and stations_number_per_person pearsonr correlation coefficient is 0.115519, p-value is 0.295379
# the pubs_number and school_number_per_person pearsonr correlation coefficient is -0.335300, p-value is 0.001822
# the pubs_number and total_jobs_per_person pearsonr correlation coefficient is -0.256399, p-value is 0.018561
# the pubs_number and number_of_universities_per_person pearsonr correlation coefficient is 0.230403, p-value is 0.034988
# the road_traffic_2015 and FrostDay_perYear pearsonr correlation coefficient is 0.361189, p-value is 0.000737
# the road_traffic_2015 and GVA pearsonr correlation coefficient is -0.213280, p-value is 0.051423
# the road_traffic_2015 and Rainfall_perMon pearsonr correlation coefficient is 0.132145, p-value is 0.230822
# the road_traffic_2015 and SummerDay_ave_temperature pearsonr correlation coefficient is -0.261419, p-value is 0.016307
# the road_traffic_2015 and SummerNight_ave_temperature pearsonr correlation coefficient is -0.390925, p-value is 0.000236
# the road_traffic_2015 and Sunshine_perMon pearsonr correlation coefficient is -0.402147, p-value is 0.000149
# the road_traffic_2015 and WinterDay_ave_temperature pearsonr correlation coefficient is -0.219184, p-value is 0.045158
# the road_traffic_2015 and WinterNight_ave_temperature pearsonr correlation coefficient is -0.396662, p-value is 0.000187
# the road_traffic_2015 and hospitals_number pearsonr correlation coefficient is 0.583169, p-value is 0.000000
# the road_traffic_2015 and house_price pearsonr correlation coefficient is -0.305893, p-value is 0.004659
# the road_traffic_2015 and number_of_universities pearsonr correlation coefficient is 0.578448, p-value is 0.000000
# the road_traffic_2015 and population pearsonr correlation coefficient is 0.510170, p-value is 0.000001
# the road_traffic_2015 and pubs_number pearsonr correlation coefficient is 0.348666, p-value is 0.001153
# the road_traffic_2015 and road_traffic_2015 pearsonr correlation coefficient is 1.000000, p-value is 0.000000
# the road_traffic_2015 and road_traffic_2016 pearsonr correlation coefficient is 0.993754, p-value is 0.000000
# the road_traffic_2015 and school_number pearsonr correlation coefficient is 0.420301, p-value is 0.000069
# the road_traffic_2015 and stations_number pearsonr correlation coefficient is 0.375279, p-value is 0.000436
# the road_traffic_2015 and total_jobs pearsonr correlation coefficient is 0.483170, p-value is 0.000003
# the road_traffic_2015 and traffic_noise pearsonr correlation coefficient is 0.452580, p-value is 0.000015
# the road_traffic_2015 and unemployment pearsonr correlation coefficient is 0.365515, p-value is 0.000629
# the road_traffic_2015 and hospitals_number_per_person pearsonr correlation coefficient is 0.081108, p-value is 0.463289
# the road_traffic_2015 and pubs_number_per_person pearsonr correlation coefficient is -0.130890, p-value is 0.235321
# the road_traffic_2015 and stations_number_per_person pearsonr correlation coefficient is -0.122985, p-value is 0.265055
# the road_traffic_2015 and school_number_per_person pearsonr correlation coefficient is -0.289410, p-value is 0.007582
# the road_traffic_2015 and total_jobs_per_person pearsonr correlation coefficient is -0.271492, p-value is 0.012486
# the road_traffic_2015 and number_of_universities_per_person pearsonr correlation coefficient is 0.261029, p-value is 0.016473
# the road_traffic_2016 and FrostDay_perYear pearsonr correlation coefficient is 0.367317, p-value is 0.000588
# the road_traffic_2016 and GVA pearsonr correlation coefficient is -0.171795, p-value is 0.118153
# the road_traffic_2016 and Rainfall_perMon pearsonr correlation coefficient is 0.118709, p-value is 0.282155
# the road_traffic_2016 and SummerDay_ave_temperature pearsonr correlation coefficient is -0.236944, p-value is 0.030000
# the road_traffic_2016 and SummerNight_ave_temperature pearsonr correlation coefficient is -0.371349, p-value is 0.000506
# the road_traffic_2016 and Sunshine_perMon pearsonr correlation coefficient is -0.391461, p-value is 0.000231
# the road_traffic_2016 and WinterDay_ave_temperature pearsonr correlation coefficient is -0.191852, p-value is 0.080414
# the road_traffic_2016 and WinterNight_ave_temperature pearsonr correlation coefficient is -0.396118, p-value is 0.000192
# the road_traffic_2016 and hospitals_number pearsonr correlation coefficient is 0.580187, p-value is 0.000000
# the road_traffic_2016 and house_price pearsonr correlation coefficient is -0.272296, p-value is 0.012218
# the road_traffic_2016 and number_of_universities pearsonr correlation coefficient is 0.567994, p-value is 0.000000
# the road_traffic_2016 and population pearsonr correlation coefficient is 0.498474, p-value is 0.000001
# the road_traffic_2016 and pubs_number pearsonr correlation coefficient is 0.336809, p-value is 0.001732
# the road_traffic_2016 and road_traffic_2015 pearsonr correlation coefficient is 0.993754, p-value is 0.000000
# the road_traffic_2016 and road_traffic_2016 pearsonr correlation coefficient is 1.000000, p-value is 0.000000
# the road_traffic_2016 and school_number pearsonr correlation coefficient is 0.403117, p-value is 0.000144
# the road_traffic_2016 and stations_number pearsonr correlation coefficient is 0.360832, p-value is 0.000747
# the road_traffic_2016 and total_jobs pearsonr correlation coefficient is 0.475115, p-value is 0.000005
# the road_traffic_2016 and traffic_noise pearsonr correlation coefficient is 0.453175, p-value is 0.000015
# the road_traffic_2016 and unemployment pearsonr correlation coefficient is 0.342667, p-value is 0.001419
# the road_traffic_2016 and hospitals_number_per_person pearsonr correlation coefficient is 0.098079, p-value is 0.374767
# the road_traffic_2016 and pubs_number_per_person pearsonr correlation coefficient is -0.158740, p-value is 0.149235
# the road_traffic_2016 and stations_number_per_person pearsonr correlation coefficient is -0.138539, p-value is 0.208836
# the road_traffic_2016 and school_number_per_person pearsonr correlation coefficient is -0.288355, p-value is 0.007815
# the road_traffic_2016 and total_jobs_per_person pearsonr correlation coefficient is -0.242052, p-value is 0.026534
# the road_traffic_2016 and number_of_universities_per_person pearsonr correlation coefficient is 0.251829, p-value is 0.020841
# the school_number and FrostDay_perYear pearsonr correlation coefficient is 0.012214, p-value is 0.912192
# the school_number and GVA pearsonr correlation coefficient is -0.167898, p-value is 0.126856
# the school_number and Rainfall_perMon pearsonr correlation coefficient is 0.066548, p-value is 0.547538
# the school_number and SummerDay_ave_temperature pearsonr correlation coefficient is -0.207363, p-value is 0.058403
# the school_number and SummerNight_ave_temperature pearsonr correlation coefficient is -0.191100, p-value is 0.081630
# the school_number and Sunshine_perMon pearsonr correlation coefficient is -0.246052, p-value is 0.024063
# the school_number and WinterDay_ave_temperature pearsonr correlation coefficient is -0.303688, p-value is 0.004980
# the school_number and WinterNight_ave_temperature pearsonr correlation coefficient is -0.107816, p-value is 0.328968
# the school_number and hospitals_number pearsonr correlation coefficient is 0.739010, p-value is 0.000000
# the school_number and house_price pearsonr correlation coefficient is -0.251881, p-value is 0.020814
# the school_number and number_of_universities pearsonr correlation coefficient is 0.606420, p-value is 0.000000
# the school_number and population pearsonr correlation coefficient is 0.810281, p-value is 0.000000
# the school_number and pubs_number pearsonr correlation coefficient is 0.528952, p-value is 0.000000
# the school_number and road_traffic_2015 pearsonr correlation coefficient is 0.420301, p-value is 0.000069
# the school_number and road_traffic_2016 pearsonr correlation coefficient is 0.403117, p-value is 0.000144
# the school_number and school_number pearsonr correlation coefficient is 1.000000, p-value is 0.000000
# the school_number and stations_number pearsonr correlation coefficient is 0.537528, p-value is 0.000000
# the school_number and total_jobs pearsonr correlation coefficient is 0.815058, p-value is 0.000000
# the school_number and traffic_noise pearsonr correlation coefficient is 0.592151, p-value is 0.000000
# the school_number and unemployment pearsonr correlation coefficient is 0.363941, p-value is 0.000666
# the school_number and hospitals_number_per_person pearsonr correlation coefficient is -0.042626, p-value is 0.700243
# the school_number and pubs_number_per_person pearsonr correlation coefficient is -0.071535, p-value is 0.517868
# the school_number and stations_number_per_person pearsonr correlation coefficient is -0.250095, p-value is 0.021767
# the school_number and school_number_per_person pearsonr correlation coefficient is 0.108757, p-value is 0.324739
# the school_number and total_jobs_per_person pearsonr correlation coefficient is -0.118527, p-value is 0.282900
# the school_number and number_of_universities_per_person pearsonr correlation coefficient is 0.179904, p-value is 0.101519
# the stations_number and FrostDay_perYear pearsonr correlation coefficient is 0.081274, p-value is 0.462372
# the stations_number and GVA pearsonr correlation coefficient is -0.338628, p-value is 0.001629
# the stations_number and Rainfall_perMon pearsonr correlation coefficient is 0.250291, p-value is 0.021661
# the stations_number and SummerDay_ave_temperature pearsonr correlation coefficient is -0.419063, p-value is 0.000073
# the stations_number and SummerNight_ave_temperature pearsonr correlation coefficient is -0.304755, p-value is 0.004822
# the stations_number and Sunshine_perMon pearsonr correlation coefficient is -0.502436, p-value is 0.000001
# the stations_number and WinterDay_ave_temperature pearsonr correlation coefficient is -0.431517, p-value is 0.000042
# the stations_number and WinterNight_ave_temperature pearsonr correlation coefficient is -0.220293, p-value is 0.044054
# the stations_number and hospitals_number pearsonr correlation coefficient is 0.618720, p-value is 0.000000
# the stations_number and house_price pearsonr correlation coefficient is -0.440073, p-value is 0.000028
# ...
# the hospitals_number_per_person and total_jobs_per_person pearsonr correlation coefficient is 0.424675, p-value is 0.000057
# the hospitals_number_per_person and number_of_universities_per_person pearsonr correlation coefficient is 0.346875, p-value is 0.001227
# the pubs_number_per_person and FrostDay_perYear pearsonr correlation coefficient is -0.031337, p-value is 0.777196
# the pubs_number_per_person and GVA pearsonr correlation coefficient is -0.374692, p-value is 0.000446
# the pubs_number_per_person and Rainfall_perMon pearsonr correlation coefficient is 0.329038, p-value is 0.002243
# the pubs_number_per_person and SummerDay_ave_temperature pearsonr correlation coefficient is -0.493210, p-value is 0.000002
# the pubs_number_per_person and SummerNight_ave_temperature pearsonr correlation coefficient is -0.221981, p-value is 0.042417
# the pubs_number_per_person and Sunshine_perMon pearsonr correlation coefficient is -0.412237, p-value is 0.000098
# the pubs_number_per_person and WinterDay_ave_temperature pearsonr correlation coefficient is -0.430959, p-value is 0.000043
# the pubs_number_per_person and WinterNight_ave_temperature pearsonr correlation coefficient is -0.115249, p-value is 0.296519
# the pubs_number_per_person and hospitals_number pearsonr correlation coefficient is 0.018754, p-value is 0.865540
# the pubs_number_per_person and house_price pearsonr correlation coefficient is -0.384126, p-value is 0.000309
# the pubs_number_per_person and number_of_universities pearsonr correlation coefficient is -0.028760, p-value is 0.795098
# the pubs_number_per_person and population pearsonr correlation coefficient is -0.203885, p-value is 0.062853
# the pubs_number_per_person and pubs_number pearsonr correlation coefficient is 0.518157, p-value is 0.000000
# the pubs_number_per_person and road_traffic_2015 pearsonr correlation coefficient is -0.130890, p-value is 0.235321
# the pubs_number_per_person and road_traffic_2016 pearsonr correlation coefficient is -0.158740, p-value is 0.149235
# the pubs_number_per_person and school_number pearsonr correlation coefficient is -0.071535, p-value is 0.517868
# the pubs_number_per_person and stations_number pearsonr correlation coefficient is 0.244899, p-value is 0.024755
# the pubs_number_per_person and total_jobs pearsonr correlation coefficient is -0.203502, p-value is 0.063360
# the pubs_number_per_person and traffic_noise pearsonr correlation coefficient is 0.102666, p-value is 0.352731
# the pubs_number_per_person and unemployment pearsonr correlation coefficient is 0.253724, p-value is 0.019868
# the pubs_number_per_person and hospitals_number_per_person pearsonr correlation coefficient is 0.123533, p-value is 0.262914
# the pubs_number_per_person and pubs_number_per_person pearsonr correlation coefficient is 1.000000, p-value is 0.000000
# the pubs_number_per_person and stations_number_per_person pearsonr correlation coefficient is 0.466321, p-value is 0.000008
# the pubs_number_per_person and school_number_per_person pearsonr correlation coefficient is 0.100800, p-value is 0.361593
# the pubs_number_per_person and total_jobs_per_person pearsonr correlation coefficient is -0.165273, p-value is 0.132992
# the pubs_number_per_person and number_of_universities_per_person pearsonr correlation coefficient is 0.105661, p-value is 0.338786
# the stations_number_per_person and FrostDay_perYear pearsonr correlation coefficient is -0.139405, p-value is 0.205977
# the stations_number_per_person and GVA pearsonr correlation coefficient is -0.181309, p-value is 0.098834
# the stations_number_per_person and Rainfall_perMon pearsonr correlation coefficient is 0.154082, p-value is 0.161693
# the stations_number_per_person and SummerDay_ave_temperature pearsonr correlation coefficient is -0.198319, p-value is 0.070545
# the stations_number_per_person and SummerNight_ave_temperature pearsonr correlation coefficient is 0.052282, p-value is 0.636701
# the stations_number_per_person and Sunshine_perMon pearsonr correlation coefficient is -0.190133, p-value is 0.083216
# the stations_number_per_person and WinterDay_ave_temperature pearsonr correlation coefficient is -0.060566, p-value is 0.584184
# the stations_number_per_person and WinterNight_ave_temperature pearsonr correlation coefficient is 0.118623, p-value is 0.282507
# the stations_number_per_person and hospitals_number pearsonr correlation coefficient is -0.089147, p-value is 0.420008
# the stations_number_per_person and house_price pearsonr correlation coefficient is -0.143259, p-value is 0.193589
# the stations_number_per_person and number_of_universities pearsonr correlation coefficient is -0.281884, p-value is 0.009385
# the stations_number_per_person and population pearsonr correlation coefficient is -0.170241, p-value is 0.121568
# the stations_number_per_person and pubs_number pearsonr correlation coefficient is 0.115519, p-value is 0.295379
# the stations_number_per_person and road_traffic_2015 pearsonr correlation coefficient is -0.122985, p-value is 0.265055
# the stations_number_per_person and road_traffic_2016 pearsonr correlation coefficient is -0.138539, p-value is 0.208836
# the stations_number_per_person and school_number pearsonr correlation coefficient is -0.250095, p-value is 0.021767
# the stations_number_per_person and stations_number pearsonr correlation coefficient is 0.475699, p-value is 0.000005
# the stations_number_per_person and total_jobs pearsonr correlation coefficient is -0.204279, p-value is 0.062336
# the stations_number_per_person and traffic_noise pearsonr correlation coefficient is 0.102227, p-value is 0.354801
# the stations_number_per_person and unemployment pearsonr correlation coefficient is 0.061535, p-value is 0.578173
# the stations_number_per_person and hospitals_number_per_person pearsonr correlation coefficient is 0.180358, p-value is 0.100645
# the stations_number_per_person and pubs_number_per_person pearsonr correlation coefficient is 0.466321, p-value is 0.000008
# the stations_number_per_person and stations_number_per_person pearsonr correlation coefficient is 1.000000, p-value is 0.000000
# the stations_number_per_person and school_number_per_person pearsonr correlation coefficient is -0.209897, p-value is 0.055324
# the stations_number_per_person and total_jobs_per_person pearsonr correlation coefficient is -0.141437, p-value is 0.199376
# the stations_number_per_person and number_of_universities_per_person pearsonr correlation coefficient is -0.157425, p-value is 0.152678
# the school_number_per_person and FrostDay_perYear pearsonr correlation coefficient is -0.224415, p-value is 0.040147
# the school_number_per_person and GVA pearsonr correlation coefficient is 0.242396, p-value is 0.026314
# the school_number_per_person and Rainfall_perMon pearsonr correlation coefficient is -0.311631, p-value is 0.003907
# the school_number_per_person and SummerDay_ave_temperature pearsonr correlation coefficient is 0.309320, p-value is 0.004196
# the school_number_per_person and SummerNight_ave_temperature pearsonr correlation coefficient is 0.329241, p-value is 0.002228
# the school_number_per_person and Sunshine_perMon pearsonr correlation coefficient is 0.415478, p-value is 0.000085
# the school_number_per_person and WinterDay_ave_temperature pearsonr correlation coefficient is 0.304829, p-value is 0.004812
# the school_number_per_person and WinterNight_ave_temperature pearsonr correlation coefficient is 0.310664, p-value is 0.004026
# the school_number_per_person and hospitals_number pearsonr correlation coefficient is -0.186655, p-value is 0.089118
# the school_number_per_person and house_price pearsonr correlation coefficient is 0.254046, p-value is 0.019707
# the school_number_per_person and number_of_universities pearsonr correlation coefficient is -0.261327, p-value is 0.016346
# the school_number_per_person and population pearsonr correlation coefficient is -0.374345, p-value is 0.000452
# the school_number_per_person and pubs_number pearsonr correlation coefficient is -0.335300, p-value is 0.001822
# the school_number_per_person and road_traffic_2015 pearsonr correlation coefficient is -0.289410, p-value is 0.007582
# the school_number_per_person and road_traffic_2016 pearsonr correlation coefficient is -0.288355, p-value is 0.007815
# the school_number_per_person and school_number pearsonr correlation coefficient is 0.108757, p-value is 0.324739
# the school_number_per_person and stations_number pearsonr correlation coefficient is -0.463326, p-value is 0.000009
# the school_number_per_person and total_jobs pearsonr correlation coefficient is -0.348693, p-value is 0.001152
# the school_number_per_person and traffic_noise pearsonr correlation coefficient is -0.494607, p-value is 0.000002
# the school_number_per_person and unemployment pearsonr correlation coefficient is -0.218783, p-value is 0.045562
# the school_number_per_person and hospitals_number_per_person pearsonr correlation coefficient is 0.356972, p-value is 0.000858
# the school_number_per_person and pubs_number_per_person pearsonr correlation coefficient is 0.100800, p-value is 0.361593
# the school_number_per_person and stations_number_per_person pearsonr correlation coefficient is -0.209897, p-value is 0.055324
# the school_number_per_person and school_number_per_person pearsonr correlation coefficient is 1.000000, p-value is 0.000000
# the school_number_per_person and total_jobs_per_person pearsonr correlation coefficient is 0.303400, p-value is 0.005024
# the school_number_per_person and number_of_universities_per_person pearsonr correlation coefficient is 0.099368, p-value is 0.368488
# the total_jobs_per_person and FrostDay_perYear pearsonr correlation coefficient is -0.002654, p-value is 0.980882
# the total_jobs_per_person and GVA pearsonr correlation coefficient is 0.587183, p-value is 0.000000
# the total_jobs_per_person and Rainfall_perMon pearsonr correlation coefficient is -0.312980, p-value is 0.003747
# the total_jobs_per_person and SummerDay_ave_temperature pearsonr correlation coefficient is 0.432943, p-value is 0.000039
# the total_jobs_per_person and SummerNight_ave_temperature pearsonr correlation coefficient is 0.289120, p-value is 0.007645
# the total_jobs_per_person and Sunshine_perMon pearsonr correlation coefficient is 0.260273, p-value is 0.016799
# the total_jobs_per_person and WinterDay_ave_temperature pearsonr correlation coefficient is 0.521375, p-value is 0.000000
# the total_jobs_per_person and WinterNight_ave_temperature pearsonr correlation coefficient is 0.160286, p-value is 0.145262
# the total_jobs_per_person and hospitals_number pearsonr correlation coefficient is -0.052740, p-value is 0.633745
# the total_jobs_per_person and house_price pearsonr correlation coefficient is 0.701414, p-value is 0.000000
# the total_jobs_per_person and number_of_universities pearsonr correlation coefficient is -0.064488, p-value is 0.560034
# the total_jobs_per_person and population pearsonr correlation coefficient is -0.218554, p-value is 0.045795
# the total_jobs_per_person and pubs_number pearsonr correlation coefficient is -0.256399, p-value is 0.018561
# the total_jobs_per_person and road_traffic_2015 pearsonr correlation coefficient is -0.271492, p-value is 0.012486
# the total_jobs_per_person and road_traffic_2016 pearsonr correlation coefficient is -0.242052, p-value is 0.026534
# the total_jobs_per_person and school_number pearsonr correlation coefficient is -0.118527, p-value is 0.282900
# the total_jobs_per_person and stations_number pearsonr correlation coefficient is -0.356980, p-value is 0.000858
# the total_jobs_per_person and total_jobs pearsonr correlation coefficient is -0.089501, p-value is 0.418156
# the total_jobs_per_person and traffic_noise pearsonr correlation coefficient is -0.292326, p-value is 0.006970
# the total_jobs_per_person and unemployment pearsonr correlation coefficient is -0.752420, p-value is 0.000000
# the total_jobs_per_person and hospitals_number_per_person pearsonr correlation coefficient is 0.424675, p-value is 0.000057
# the total_jobs_per_person and pubs_number_per_person pearsonr correlation coefficient is -0.165273, p-value is 0.132992
# the total_jobs_per_person and stations_number_per_person pearsonr correlation coefficient is -0.141437, p-value is 0.199376
# the total_jobs_per_person and school_number_per_person pearsonr correlation coefficient is 0.303400, p-value is 0.005024
# the total_jobs_per_person and total_jobs_per_person pearsonr correlation coefficient is 1.000000, p-value is 0.000000
# the total_jobs_per_person and number_of_universities_per_person pearsonr correlation coefficient is 0.157101, p-value is 0.153533
# the number_of_universities_per_person and FrostDay_perYear pearsonr correlation coefficient is 0.047760, p-value is 0.666169
# the number_of_universities_per_person and GVA pearsonr correlation coefficient is -0.187233, p-value is 0.088116
# the number_of_universities_per_person and Rainfall_perMon pearsonr correlation coefficient is 0.116573, p-value is 0.290967
# the number_of_universities_per_person and SummerDay_ave_temperature pearsonr correlation coefficient is -0.161566, p-value is 0.142034
# the number_of_universities_per_person and SummerNight_ave_temperature pearsonr correlation coefficient is -0.108709, p-value is 0.324956
# the number_of_universities_per_person and Sunshine_perMon pearsonr correlation coefficient is -0.151527, p-value is 0.168846
# the number_of_universities_per_person and WinterDay_ave_temperature pearsonr correlation coefficient is -0.031174, p-value is 0.778323
# the number_of_universities_per_person and WinterNight_ave_temperature pearsonr correlation coefficient is -0.009767, p-value is 0.929735
# the number_of_universities_per_person and hospitals_number pearsonr correlation coefficient is 0.330241, p-value is 0.002156
# the number_of_universities_per_person and house_price pearsonr correlation coefficient is 0.115900, p-value is 0.293777
# the number_of_universities_per_person and number_of_universities pearsonr correlation coefficient is 0.690869, p-value is 0.000000
# the number_of_universities_per_person and population pearsonr correlation coefficient is 0.108700, p-value is 0.324996
# the number_of_universities_per_person and pubs_number pearsonr correlation coefficient is 0.230403, p-value is 0.034988
# the number_of_universities_per_person and road_traffic_2015 pearsonr correlation coefficient is 0.261029, p-value is 0.016473
# the number_of_universities_per_person and road_traffic_2016 pearsonr correlation coefficient is 0.251829, p-value is 0.020841
# the number_of_universities_per_person and school_number pearsonr correlation coefficient is 0.179904, p-value is 0.101519
# the number_of_universities_per_person and stations_number pearsonr correlation coefficient is 0.008775, p-value is 0.936856
# the number_of_universities_per_person and total_jobs pearsonr correlation coefficient is 0.138047, p-value is 0.210470
# the number_of_universities_per_person and traffic_noise pearsonr correlation coefficient is 0.130248, p-value is 0.237645
# the number_of_universities_per_person and unemployment pearsonr correlation coefficient is -0.030141, p-value is 0.785494
# the number_of_universities_per_person and hospitals_number_per_person pearsonr correlation coefficient is 0.346875, p-value is 0.001227
# the number_of_universities_per_person and pubs_number_per_person pearsonr correlation coefficient is 0.105661, p-value is 0.338786
# the number_of_universities_per_person and stations_number_per_person pearsonr correlation coefficient is -0.157425, p-value is 0.152678
# the number_of_universities_per_person and school_number_per_person pearsonr correlation coefficient is 0.099368, p-value is 0.368488
# the number_of_universities_per_person and total_jobs_per_person pearsonr correlation coefficient is 0.157101, p-value is 0.153533
# the number_of_universities_per_person and number_of_universities_per_person pearsonr correlation coefficient is 1.000000, p-value is 0.000000
